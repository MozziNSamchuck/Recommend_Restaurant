# %%
# %cd /content/drive/MyDrive/Emotion_Analysis
# Out:
# /content/drive/MyDrive/Emotion_Analysis

# %%
pwd
# Out:
# '/content/drive/MyDrive'

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
import pandas as pd

# Load data
data = pd.read_excel('restaurant_reviews_emotion.xlsx')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Split text into a list
data['text'] = data['text'].str.split('.')

# %%
# Convert list into multiple rows
data = data.explode('text')
print(data)
# Out:
#            name  rating                                               text  \
# 0         가마솥곰탕       4     The only gomtang restaurant in Innovation City
# 0         가마솥곰탕       4  \nRich broth, plenty of meat, reasonable price...
# 0         가마솥곰탕       4                 \nThe staff are also very friendly
# 0         가마솥곰탕       4  \nYou can see gomtang being boiled in a real c...
# 0         가마솥곰탕       4  \nIn addition to gomtang, they also sell boile...
# ..          ...     ...                                                ...
# 50  돈까스식당 신서혁신점       2     \nTaste and service you won't go back to again
# 51  돈까스식당 신서혁신점       5  I came here for the first time in a while and ...
# 51  돈까스식당 신서혁신점       5
# 52         백숙명당       5         The taste of clean samgyetang is excellent
# 52         백숙명당       5
#
#       category
# 0         full
# 0         full
# 0         full
# 0         full
# 0         full
# ..         ...
# 50  disappoint
# 51       taste
# 51       taste
# 52       taste
# 52       taste
#
# [181 rows x 4 columns]

# %%
# Clean and transform data
data = data.drop_duplicates()
data = data.reset_index(drop=True)
print(data)
# Out:
#             name  rating                                               text  \
# 0          가마솥곰탕       4     The only gomtang restaurant in Innovation City
# 1          가마솥곰탕       4  \nRich broth, plenty of meat, reasonable price...
# 2          가마솥곰탕       4                 \nThe staff are also very friendly
# 3          가마솥곰탕       4  \nYou can see gomtang being boiled in a real c...
# 4          가마솥곰탕       4  \nIn addition to gomtang, they also sell boile...
# ..           ...     ...                                                ...
# 150  돈까스식당 신서혁신점       2  \nI stopped by here because it was the only po...
# 151  돈까스식당 신서혁신점       2     \nTaste and service you won't go back to again
# 152  돈까스식당 신서혁신점       5  I came here for the first time in a while and ...
# 153         백숙명당       5         The taste of clean samgyetang is excellent
# 154         백숙명당       5
#
#        category
# 0          full
# 1          full
# 2          full
# 3          full
# 4          full
# ..          ...
# 150  disappoint
# 151  disappoint
# 152       taste
# 153       taste
# 154       taste
#
# [155 rows x 4 columns]

# %%
# Split text into a list
data['text'] = data['text'].str.split('!')

# %%
# Convert list into multiple rows
data = data.explode('text')
print(data)
# Out:
#             name  rating                                               text  \
# 0          가마솥곰탕       4     The only gomtang restaurant in Innovation City
# 1          가마솥곰탕       4  \nRich broth, plenty of meat, reasonable price...
# 2          가마솥곰탕       4                 \nThe staff are also very friendly
# 3          가마솥곰탕       4  \nYou can see gomtang being boiled in a real c...
# 4          가마솥곰탕       4  \nIn addition to gomtang, they also sell boile...
# ..           ...     ...                                                ...
# 150  돈까스식당 신서혁신점       2  \nI stopped by here because it was the only po...
# 151  돈까스식당 신서혁신점       2     \nTaste and service you won't go back to again
# 152  돈까스식당 신서혁신점       5  I came here for the first time in a while and ...
# 153         백숙명당       5         The taste of clean samgyetang is excellent
# 154         백숙명당       5
#
#        category
# 0          full
# 1          full
# 2          full
# 3          full
# 4          full
# ..          ...
# 150  disappoint
# 151  disappoint
# 152       taste
# 153       taste
# 154       taste
#
# [159 rows x 4 columns]

# %%
# Clean and transform data
data = data.drop_duplicates()
data = data.reset_index(drop=True)
print(data)
# Out:
#             name  rating                                               text  \
# 0          가마솥곰탕       4     The only gomtang restaurant in Innovation City
# 1          가마솥곰탕       4  \nRich broth, plenty of meat, reasonable price...
# 2          가마솥곰탕       4                 \nThe staff are also very friendly
# 3          가마솥곰탕       4  \nYou can see gomtang being boiled in a real c...
# 4          가마솥곰탕       4  \nIn addition to gomtang, they also sell boile...
# ..           ...     ...                                                ...
# 152  돈까스식당 신서혁신점       2  \nI stopped by here because it was the only po...
# 153  돈까스식당 신서혁신점       2     \nTaste and service you won't go back to again
# 154  돈까스식당 신서혁신점       5  I came here for the first time in a while and ...
# 155         백숙명당       5         The taste of clean samgyetang is excellent
# 156         백숙명당       5
#
#        category
# 0          full
# 1          full
# 2          full
# 3          full
# 4          full
# ..          ...
# 152  disappoint
# 153  disappoint
# 154       taste
# 155       taste
# 156       taste
#
# [157 rows x 4 columns]

# %%
# Split text into a list
data['text'] = data['text'].str.split('?')

# %%
# Convert list into multiple rows
data = data.explode('text')
print(data)
# Out:
#             name  rating                                               text  \
# 0          가마솥곰탕       4     The only gomtang restaurant in Innovation City
# 1          가마솥곰탕       4  \nRich broth, plenty of meat, reasonable price...
# 2          가마솥곰탕       4                 \nThe staff are also very friendly
# 3          가마솥곰탕       4  \nYou can see gomtang being boiled in a real c...
# 4          가마솥곰탕       4  \nIn addition to gomtang, they also sell boile...
# ..           ...     ...                                                ...
# 152  돈까스식당 신서혁신점       2  \nI stopped by here because it was the only po...
# 153  돈까스식당 신서혁신점       2     \nTaste and service you won't go back to again
# 154  돈까스식당 신서혁신점       5  I came here for the first time in a while and ...
# 155         백숙명당       5         The taste of clean samgyetang is excellent
# 156         백숙명당       5
#
#        category
# 0          full
# 1          full
# 2          full
# 3          full
# 4          full
# ..          ...
# 152  disappoint
# 153  disappoint
# 154       taste
# 155       taste
# 156       taste
#
# [157 rows x 4 columns]

# %%
# Clean and transform data
data = data.drop_duplicates()
data = data.reset_index(drop=True)
print(data)
# Out:
#             name  rating                                               text  \
# 0          가마솥곰탕       4     The only gomtang restaurant in Innovation City
# 1          가마솥곰탕       4  \nRich broth, plenty of meat, reasonable price...
# 2          가마솥곰탕       4                 \nThe staff are also very friendly
# 3          가마솥곰탕       4  \nYou can see gomtang being boiled in a real c...
# 4          가마솥곰탕       4  \nIn addition to gomtang, they also sell boile...
# ..           ...     ...                                                ...
# 152  돈까스식당 신서혁신점       2  \nI stopped by here because it was the only po...
# 153  돈까스식당 신서혁신점       2     \nTaste and service you won't go back to again
# 154  돈까스식당 신서혁신점       5  I came here for the first time in a while and ...
# 155         백숙명당       5         The taste of clean samgyetang is excellent
# 156         백숙명당       5
#
#        category
# 0          full
# 1          full
# 2          full
# 3          full
# 4          full
# ..          ...
# 152  disappoint
# 153  disappoint
# 154       taste
# 155       taste
# 156       taste
#
# [157 rows x 4 columns]

# %%
# Split text into a list
data['text'] = data['text'].str.split('\n')

# %%
# Convert list into multiple rows
data = data.explode('text')
print(data)
# Out:
#             name  rating                                               text  \
# 0          가마솥곰탕       4     The only gomtang restaurant in Innovation City
# 1          가마솥곰탕       4
# 1          가마솥곰탕       4       Rich broth, plenty of meat, reasonable price
# 1          가마솥곰탕       4                           There is nothing lacking
# 2          가마솥곰탕       4
# ..           ...     ...                                                ...
# 153  돈까스식당 신서혁신점       2
# 153  돈까스식당 신서혁신점       2       Taste and service you won't go back to again
# 154  돈까스식당 신서혁신점       5  I came here for the first time in a while and ...
# 155         백숙명당       5         The taste of clean samgyetang is excellent
# 156         백숙명당       5
#
#        category
# 0          full
# 1          full
# 1          full
# 1          full
# 2          full
# ..          ...
# 153  disappoint
# 153  disappoint
# 154       taste
# 155       taste
# 156       taste
#
# [215 rows x 4 columns]

# %%
# Clean and transform data
data = data.drop_duplicates()
data = data.reset_index(drop=True)
print(data)
# Out:
#             name  rating                                               text  \
# 0          가마솥곰탕       4     The only gomtang restaurant in Innovation City
# 1          가마솥곰탕       4
# 2          가마솥곰탕       4       Rich broth, plenty of meat, reasonable price
# 3          가마솥곰탕       4                           There is nothing lacking
# 4          가마솥곰탕       4                   The staff are also very friendly
# ..           ...     ...                                                ...
# 162  돈까스식당 신서혁신점       2  I stopped by here because it was the only pork...
# 163  돈까스식당 신서혁신점       2       Taste and service you won't go back to again
# 164  돈까스식당 신서혁신점       5  I came here for the first time in a while and ...
# 165         백숙명당       5         The taste of clean samgyetang is excellent
# 166         백숙명당       5
#
#        category
# 0          full
# 1          full
# 2          full
# 3          full
# 4          full
# ..          ...
# 162  disappoint
# 163  disappoint
# 164       taste
# 165       taste
# 166       taste
#
# [167 rows x 4 columns]

# %%
# Export data
data.to_excel('cleaned_data2.xlsx', index=False)
